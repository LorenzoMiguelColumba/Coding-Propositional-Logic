# %% [markdown]
# # Propositional Logic

# %% [markdown]
# ## DisMath_Coding_Lab1

# %% [markdown]
# submitted by:

# %% [markdown]
# Columba, Lorenzo Miguel L.

# %% [markdown]
# 58007

# %% [markdown]
# ### Given English Statement:

# %% [markdown]
# #### Add additional fries and drinks to the order if the customer would buy a Cheese Burger Deluxe and add a Sundae instead if they also do. Always remember to print the receipt for every transaction.

# %% [markdown]
# p: Add additional fries and drinks

# %% [markdown]
# q: the customer would buy a cheese burger deluxe

# %% [markdown]
# r: Add sundae

# %% [markdown]
# WFF:  $(p\rightarrow q)  \land (\neg p \rightarrow r)$

# %% [markdown]
# Flowchart:

# %% [markdown]
# ![Proposition (1).jpeg](attachment:f2be95b9-e47d-4de1-862e-bf3167caadc5.jpeg)

# %% [markdown]
# Code as:

# %%
buyCheesBurgerDeluxe = True
if(buyCheesBurgerDeluxe):
    print(" Cheese burger deluxe with fries and drinks")
    print(" Orders complete")
else:
    print("Cheese burger deluxe with sundae")
    print(" Orders complete")
# Out:
#  Cheese burger deluxe with fries and drinks
#  Orders complete

# %% [markdown]
# Code Explanation:

# %% [markdown]
# The code for this is,  If it's true, the customer will get a cheese burger deluxe, it'll automatically add the extra fries and drinks followed by a receipt. Otherwise, if it is false, the customer will buy a cheese burger deluxe and can a add ice-cream sundae because the substitute for the fries and drinks then print a receiept.

# %% [markdown]
# ### Given Pseudocode

# %% [markdown]
# ![d.JPG](attachment:f77d21bf-9396-45fb-a8b3-9d5dc255a1d2.JPG)

# %% [markdown]
# ### Convert to English Statement

# %% [markdown]
# #### The reservoir level is at 5mm, if the rain gauge measures 10mm, it will transfer to the resource.

# %% [markdown]
#  p: the normal reservoir level is at 5mm

# %% [markdown]
# q: the reservoir level reaches at 10mm

# %% [markdown]
# r: It will transfer to the resource

# %% [markdown]
# WFF: $p \rightarrow (q\rightarrow r)$

# %% [markdown]
# Flowchart:

# %% [markdown]
# ![Blank diagram.png](attachment:ba979176-aee0-47ab-a869-b6c7a622e6f8.png)
